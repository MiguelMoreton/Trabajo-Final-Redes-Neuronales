# %%
import numpy as np
import torch
from torch.utils.data import DataLoader, TensorDataset, random_split
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

# %% [markdown]
# ## Carga de datos de entrenamiento, división para obtener algunos de test y ampliación con transformaciones
# En esta versión, **primero** se reconstruye cada imagen a tamaño **80x70**, **después** se aplican las transformaciones y **al final** se aplana para entrenar la red fully connected.

# %%
x_path = "X_train.npz"
y_path = "Y_train.npz"

def cargar_npz(ruta):
    data = np.load(ruta)
    
    # Si es un .npz, sacamos el primer array que contenga
    if isinstance(data, np.lib.npyio.NpzFile):
        if len(data.files) == 0:
            raise ValueError(f"El archivo {ruta} no contiene arrays")
        array = data[data.files[0]]
    else:
        array = data
    
    return array

try:
    X = cargar_npz(x_path)
    Y = cargar_npz(y_path)
except FileNotFoundError:
    raise ValueError("No se encuentran X_train.npz o Y_train.npz dentro de la carpeta datasets")
except Exception as e:
    raise ValueError(f"Error al cargar los datos: {e}")

print("Shape de X:", X.shape)
print("Shape de Y:", Y.shape)
# Out:
# Shape de X: (240, 5600)
# Shape de Y: (240,)

# %%
# Pasar a tensores
X = torch.tensor(X, dtype=torch.float32)
Y = torch.tensor(Y, dtype=torch.long)

# Normalizar si son píxeles 0-255
X = X / 255.0

IMAGE_HEIGHT = 80
IMAGE_WIDTH = 70
IMAGE_SIZE = IMAGE_HEIGHT * IMAGE_WIDTH

def to_image_80x70(x):
    """Convierte una muestra en una imagen [1, 80, 70]."""
    if x.ndim == 1:
        if x.numel() != IMAGE_SIZE:
            raise ValueError(f"Se esperaban {IMAGE_SIZE} píxeles, pero llegaron {x.numel()}")
        return x.view(1, IMAGE_HEIGHT, IMAGE_WIDTH)

    if x.ndim == 2:
        if tuple(x.shape) != (IMAGE_HEIGHT, IMAGE_WIDTH):
            raise ValueError(f"Se esperaba una imagen de forma {(IMAGE_HEIGHT, IMAGE_WIDTH)}, pero llegó {tuple(x.shape)}")
        return x.unsqueeze(0)

    if x.ndim == 3:
        if tuple(x.shape) == (1, IMAGE_HEIGHT, IMAGE_WIDTH):
            return x
        raise ValueError(f"Se esperaba una imagen de forma {(1, IMAGE_HEIGHT, IMAGE_WIDTH)}, pero llegó {tuple(x.shape)}")

    raise ValueError(f"Forma de imagen no soportada: {tuple(x.shape)}")

def flatten_image(img):
    """Aplana una imagen [1, 80, 70] a un vector de 5600 componentes."""
    if tuple(img.shape) != (1, IMAGE_HEIGHT, IMAGE_WIDTH):
        raise ValueError(f"Se esperaba una imagen de forma {(1, IMAGE_HEIGHT, IMAGE_WIDTH)}, pero llegó {tuple(img.shape)}")
    return img.reshape(-1)

rotation_transform = transforms.RandomRotation((10, 10))
horizontal_flip_transform = transforms.RandomHorizontalFlip(p=1.0)

# Dataset base con entradas y etiquetas
dataset = TensorDataset(X, Y)

# %%
generator = torch.Generator().manual_seed(42)
train_dataset_base, test_dataset = random_split(dataset, [160, 80], generator=generator)

def augment_training_subset(subset):
    x_augmented = []
    y_augmented = []

    for x, y in subset:
        img = to_image_80x70(x)

        # Imagen original (ya montada en 80x70 y luego aplanada)
        x_augmented.append(flatten_image(img))
        y_augmented.append(y)

        # Nueva imagen rotada +10 grados
        rotated_img = rotation_transform(img)
        x_augmented.append(flatten_image(rotated_img))
        y_augmented.append(y)

        # Nueva imagen con espejo horizontal
        flipped_img = horizontal_flip_transform(img)
        x_augmented.append(flatten_image(flipped_img))
        y_augmented.append(y)

    return TensorDataset(torch.stack(x_augmented), torch.stack(y_augmented))

def flatten_subset(subset):
    x_flattened = []
    y_flattened = []

    for x, y in subset:
        img = to_image_80x70(x)
        x_flattened.append(flatten_image(img))
        y_flattened.append(y)

    return TensorDataset(torch.stack(x_flattened), torch.stack(y_flattened))

train_dataset = augment_training_subset(train_dataset_base)
test_dataset = flatten_subset(test_dataset)

N_training = len(train_dataset)
N_test = len(test_dataset)

print("Total original:", len(dataset))
print("Train original:", len(train_dataset_base))
print("Train con augmentación:", len(train_dataset))
print("Test:", len(test_dataset))
# Out:
# Total original: 240
# Train original: 160
# Train con augmentación: 480
# Test: 80

# %% [markdown]
# ## Visualización de algunas imágenes tras las transformaciones
# Ejecuta esta celda para comparar imágenes del conjunto de entrenamiento **ya reconstruidas a 80x70** con sus versiones rotadas y espejadas.

# %%
# Visualización de ejemplos de augmentación
num_examples = 3  # puedes cambiarlo si quieres ver más o menos ejemplos
indices = torch.randperm(len(train_dataset_base))[:num_examples]

fig, axes = plt.subplots(num_examples, 3, figsize=(10, 3 * num_examples))

if num_examples == 1:
    axes = np.expand_dims(axes, axis=0)

for row, idx in enumerate(indices):
    x, y = train_dataset_base[idx]
    img = to_image_80x70(x)

    original_img = img.squeeze(0).cpu().numpy()
    rotated_img = rotation_transform(img).squeeze(0).cpu().numpy()
    flipped_img = horizontal_flip_transform(img).squeeze(0).cpu().numpy()

    images = [original_img, rotated_img, flipped_img]
    titles = [f"Original 80x70 | clase {int(y)}", "Rotación +10°", "Espejo horizontal"]

    for col, (image, title) in enumerate(zip(images, titles)):
        axes[row, col].imshow(image, cmap="gray")
        axes[row, col].set_title(title)
        axes[row, col].axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# Definimos la funcion metric para medir el rendimiento de nuestro modelo

# %%
def linear_link(x):
    return x

class FCLayer(nn.Module):
    def __init__(self, dim_in, dim_out, act, drop, batch_norm, add_residual):
        super().__init__()
        ## create parameters
        self.linear = nn.Linear(dim_in, dim_out)
        self.act = act
        self.drop = nn.Dropout(p = drop)
        if batch_norm:
            self.bn = nn.BatchNorm1d(dim_out)
        else:
            self.bn = linear_link

        self.add_residual = add_residual
        # when residual is needed we need to readapt input
        if add_residual and dim_in != dim_out:
            self.bottleneck = nn.Linear(dim_in,dim_out)
        else:
            self.bottleneck = linear_link

        self.traced_grads = {}

    def forward(self, x):
        fx = self.drop(self.act(self.bn(self.linear(x))))
        if self.add_residual:
            fx = self.bottleneck(x) + fx
        return fx

    def trace_gradients(self):
        for k, v in self.named_parameters():
            if k in self.traced_grads.keys():
                self.traced_grads[k].append( v.grad.data.clone() )
            else:
                self.traced_grads[k] = [v.grad.data.clone()]

    def reset_traced_grads(self):
        self.traced_grads = {}

    def get_traced_grads(self):
        return self.traced_grads

class FCDNN(nn.Module):
    def __init__(self, dim_in, dim_out, neurons_hidden : list, hidden_activations:list, dropout_hidden, batch_norm: bool, add_residual:bool, link_function, loss_function):
        super().__init__()

        assert len(neurons_hidden) == len(hidden_activations), "List specifying hidden activations and number of hidden layers must coincide"
        assert len(neurons_hidden) == len(dropout_hidden), "List specifying hidden activations and dropout per layer"


        module_list = nn.ModuleList([])

        # input layer hidden layers
        for num_neur, act, drop in zip(neurons_hidden, hidden_activations, dropout_hidden):
            module_list.append(FCLayer(dim_in, num_neur, act, drop, batch_norm, add_residual))
            dim_in = num_neur

        # output layer
        o_layer = FCLayer(dim_in, dim_out, act = linear_link, drop = 0.0, batch_norm = False, add_residual = False)
        module_list.append(o_layer)

        self.layers = module_list

        ## Loss and link function
        self.link = link_function
        self.loss = loss_function

    def forward_train(self,x, apply_link):
        self.train()

        for l in self.layers:
            x = l(x)
        y = x
        if apply_link:
            y = self.link(y)

        return y

    def forward_eval(self,x, apply_link):
        self.eval()

        for l in self.layers:
            x = l(x)
        y = x
        if apply_link:
            y = self.link(y)

        return y

    def compute_loss(self,t,y):
        return self.loss(y,t)

    def get_internal_representations(self, x, apply_link):
        internals = {}
        # exclude output layer projection since this method gets internal representations
        for i, l in enumerate(self.layers[:-1]):
            x = l(x)
            internals[f'layer {i+1}']= x
        return internals

    def trace_gradients(self):
        for l in self.layers:
            l.trace_gradients()

    def reset_traced_grads(self):
        for l in self.layers:
            l.reset_traced_grads()

    def get_traced_grads(self):
        traced_grads = {}
        for i,l in enumerate(self.layers):
            traced_grads[f'layer {i+1}'] = l.get_traced_grads()

        return traced_grads

# %%
def compute_metric(dataloader, model):
    acc = 0
    tot_samples = 0

    for x, t in dataloader:
        x, t = x.to(device), t.to(device)
        y = model.forward_eval(x, apply_link=False)

        acc += (t == torch.argmax(y, dim=1)).sum().item()
        tot_samples += len(t)

    return acc / tot_samples

def compute_metric_top3(dataloader, model, k=3):
    acc = compute_metric(dataloader, model)

    top_k_acc = 0
    tot_samples = 0

    model.eval()
    with torch.no_grad():
        for x, t in dataloader:
            x, t = x.to(device), t.to(device)
            y = model.forward_eval(x, apply_link=False)

            top_k_preds = torch.topk(y, k=k, dim=1).indices
            top_k_acc += top_k_preds.eq(t.view(-1, 1)).any(dim=1).sum().item()
            tot_samples += len(t)

    top_k_acc = top_k_acc / tot_samples
    global_metric = 0.7 * acc + 0.3 * top_k_acc

    return acc, top_k_acc, global_metric

# %%
def test_model(
    model : torch.nn.Module,
    epochs : int,
    train_batch_size : int,
    lr : float,
    mmu : float,
    apply_scheduler : bool,
    eval_each : int,
    train_dataset : torchvision.datasets,
    test_dataset : torchvision.datasets
):
    transform = transforms.Compose([
    transforms.ToTensor(),
    #meter transformación a vector
    transforms.Lambda(lambda x: x.view(-1))
])
    
#Generate train and test loaders
    train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=train_batch_size, shuffle=True)
    train_loader_eval = torch.utils.data.DataLoader(train_dataset, batch_size=train_batch_size, shuffle=False)
    test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=train_batch_size, shuffle=False)

    
## =============================== ##
    ## Compute stats at initialization ##
    ## =============================== ##
    ## Variables to monitor things
    loss_epochs = []
    train_acc_epochs = []
    test_acc_epochs = []
    train_top3_epochs = []
    test_top3_epochs = []
    train_global_epochs = []
    test_global_epochs = []

    with torch.no_grad():
        ## Compute cross entropy loss at initialization.
        loss_acc = 0.0
        for batch_idx, (x,t) in enumerate(train_loader_eval):

            ## move data to device and reshape
            x, t = x.to(device), t.to(device)

            ## forward
            y = model.forward_train(x, apply_link = False)
            L = model.compute_loss(t,y)
            loss_acc += len(x)*L.item()

        ## compute accuracies per sample
        train_acc, train_top3, train_global = compute_metric_top3(train_loader_eval, model, k=3)
        test_acc, test_top3, test_global = compute_metric_top3(test_loader, model, k=3)

    loss_epochs.append(loss_acc/N_training)
    train_acc_epochs.append(train_acc)
    test_acc_epochs.append(test_acc)
    train_top3_epochs.append(train_top3)
    test_top3_epochs.append(test_top3)
    train_global_epochs.append(train_global)
    test_global_epochs.append(test_global)

    ## ================= ##
    ## Training Pipeline ##
    ## ================= ##
    optimizer = torch.optim.SGD(model.parameters(), lr = lr, momentum = mmu)
    ## [20,80] or [10], [20,60]
    scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones = [200,400], gamma=0.1)

    for e in range(epochs):
        loss_acc = 0.0
        for batch_idx, (x,t) in enumerate(train_loader):

            ## move data to device and reshape
            x, t = x.to(device), t.to(device)

            ## forward
            y = model.forward_train(x, apply_link = False)
            L = model.compute_loss(t,y)
            loss_acc += len(x)*L.item()

            ## backward
            L.backward()

            ## Optimizer step
            optimizer.step()

            ## Optimizer zero grad
            optimizer.zero_grad()

            ## loss per batch
            print(f"On epoch {e+1} batch_idx {batch_idx + 1} got loss {L.item():.5f}", end = "\r")

        ## learning rate scheduling.
        if apply_scheduler:
            scheduler.step()

        ## Evaluate model and draw plots using threads to speed up computations.
        if (e + 1) % eval_each == 0 or e == 0:
            with torch.no_grad():

                ## compute accuracies per sample
                train_acc, train_top3, train_global = compute_metric_top3(train_loader_eval, model, k=3)
                test_acc, test_top3, test_global = compute_metric_top3(test_loader, model, k=3)

            ## total loss on training set
            print(" "*200, end="\r")
            print(
                f"On epoch {e+1} got loss {loss_acc/N_training:.5f} "
                f"with train accuracy {train_acc:.5f}, train top3 {train_top3:.5f}, train global {train_global:.5f} "
                f"and test accuracy {test_acc:.5f}, test top3 {test_top3:.5f}, test global {test_global:.5f}"
            )


        else:
            ## total loss on training set
            print(" "*200, end="\r")
            print(f"On epoch {e+1} got loss {loss_acc/N_training:.5f}")

        loss_epochs.append(loss_acc/N_training)
        train_acc_epochs.append(train_acc)
        test_acc_epochs.append(test_acc)
        train_top3_epochs.append(train_top3)
        test_top3_epochs.append(test_top3)
        train_global_epochs.append(train_global)
        test_global_epochs.append(test_global) 
        
    return loss_epochs, train_acc_epochs, test_acc_epochs, train_top3_epochs, test_top3_epochs, train_global_epochs, test_global_epochs

# %% [markdown]
# First test

# %%
torch.manual_seed(0)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print("Usando:", device)

## ============== ##
## Model Creation ##
## ============== ##
dim_in = 5600
dim_out = 40
num_h = 3
neu_h = 256
model = FCDNN(
              dim_in = dim_in,
              dim_out = dim_out,
              neurons_hidden = [256,256,256], #[neu_h] * num_h,
              hidden_activations = [torch.relu] * num_h,
              dropout_hidden = [0.5, 0.4, 0.3], #* num_h,
              batch_norm = True,
              add_residual = False,
              link_function = torch.softmax,
              loss_function = nn.CrossEntropyLoss(),
             )
model.to(device)


three_drop05_loss, three_drop05_train_acc, three_drop05_test_acc, three_drop05_train_top3, three_drop05_test_top3, three_drop05_train_global, three_drop05_test_global = test_model(
        model,
        epochs = 1200,
        lr = 0.003,
        mmu = 0.8,
        train_batch_size = 32,
        apply_scheduler = True,
        eval_each = 1,
        train_dataset = train_dataset,
        test_dataset = test_dataset
)
# Out:
# Usando: cuda
# On epoch 1 got loss 3.70454 with train accuracy 0.07917, train top3 0.19375, train global 0.11354 and test accuracy 0.03750, test top3 0.08750, test global 0.05250
# On epoch 2 got loss 3.46036 with train accuracy 0.19375, train top3 0.42500, train global 0.26312 and test accuracy 0.05000, test top3 0.22500, test global 0.10250
# On epoch 3 got loss 3.28747 with train accuracy 0.30000, train top3 0.59583, train global 0.38875 and test accuracy 0.08750, test top3 0.28750, test global 0.14750
# On epoch 4 got loss 3.08073 with train accuracy 0.46458, train top3 0.77083, train global 0.55646 and test accuracy 0.10000, test top3 0.43750, test global 0.20125
# On epoch 5 got loss 2.96027 with train accuracy 0.55625, train top3 0.82083, train global 0.63562 and test accuracy 0.20000, test top3 0.50000, test global 0.29000
# On epoch 6 got loss 2.79484 with train accuracy 0.60208, train top3 0.87083, train global 0.68271 and test accuracy 0.28750, test top3 0.52500, test global 0.35875
# On epoch 7 got loss 2.65781 with train accuracy 0.61042, train top3 0.86667, train global 0.68729 and test accuracy 0.28750, test top3 0.52500, test global 0.35875
# On epoch 8 got loss 2.53288 with train accuracy 0.70625, train top3 0.89375, train global 0.76250 and test accuracy 0.32500, test top3 0.57500, test global 0.40000
# On epoch 9 got loss 2.41044 with train accuracy 0.69583, train top3 0.89167, train global 0.75458 and test accuracy 0.32500, test top3 0.61250, test global 0.41125
# On epoch 10 got loss 2.33745 with train accuracy 0.74792, train top3 0.90833, train global 0.79604 and test accuracy 0.36250, test top3 0.66250, test global 0.45250
# On epoch 11 got loss 2.17438 with train accuracy 0.76458, train top3 0.91875, train global 0.81083 and test accuracy 0.36250, test top3 0.66250, test global 0.45250
# On epoch 12 got loss 2.09690 with train accuracy 0.77292, train top3 0.93958, train global 0.82292 and test accuracy 0.45000, test top3 0.66250, test global 0.51375
# On epoch 13 got loss 2.04776 with train accuracy 0.82500, train top3 0.95208, train global 0.86312 and test accuracy 0.43750, test top3 0.72500, test global 0.52375
# On epoch 14 got loss 1.89215 with train accuracy 0.81875, train top3 0.93542, train global 0.85375 and test accuracy 0.41250, test top3 0.73750, test global 0.51000
# On epoch 15 got loss 1.76923 with train accuracy 0.84167, train top3 0.96250, train global 0.87792 and test accuracy 0.45000, test top3 0.72500, test global 0.53250
# On epoch 16 got loss 1.70974 with train accuracy 0.85417, train top3 0.96667, train global 0.88792 and test accuracy 0.51250, test top3 0.72500, test global 0.57625
# On epoch 17 got loss 1.69777 with train accuracy 0.88125, train top3 0.98333, train global 0.91187 and test accuracy 0.50000, test top3 0.76250, test global 0.57875
# On epoch 18 got loss 1.54399 with train accuracy 0.87083, train top3 0.96250, train global 0.89833 and test accuracy 0.50000, test top3 0.76250, test global 0.57875
# On epoch 19 got loss 1.46945 with train accuracy 0.89167, train top3 0.97292, train global 0.91604 and test accuracy 0.56250, test top3 0.78750, test global 0.63000
# On epoch 20 got loss 1.37733 with train accuracy 0.90417, train top3 0.97708, train global 0.92604 and test accuracy 0.50000, test top3 0.77500, test global 0.58250
# On epoch 21 got loss 1.31356 with train accuracy 0.92917, train top3 0.98125, train global 0.94479 and test accuracy 0.58750, test top3 0.80000, test global 0.65125
# On epoch 22 got loss 1.31289 with train accuracy 0.92083, train top3 0.98125, train global 0.93896 and test accuracy 0.60000, test top3 0.80000, test global 0.66000
# On epoch 23 got loss 1.21309 with train accuracy 0.93958, train top3 0.98333, train global 0.95271 and test accuracy 0.63750, test top3 0.80000, test global 0.68625
# On epoch 24 got loss 1.17352 with train accuracy 0.93333, train top3 0.98333, train global 0.94833 and test accuracy 0.63750, test top3 0.85000, test global 0.70125
# On epoch 25 got loss 1.17463 with train accuracy 0.94167, train top3 0.99167, train global 0.95667 and test accuracy 0.61250, test top3 0.83750, test global 0.68000
# On epoch 26 got loss 1.04592 with train accuracy 0.94792, train top3 0.99792, train global 0.96292 and test accuracy 0.65000, test top3 0.82500, test global 0.70250
# On epoch 27 got loss 1.01405 with train accuracy 0.95000, train top3 1.00000, train global 0.96500 and test accuracy 0.67500, test top3 0.82500, test global 0.72000
# On epoch 28 got loss 1.00760 with train accuracy 0.96042, train top3 0.99792, train global 0.97167 and test accuracy 0.71250, test top3 0.83750, test global 0.75000
# On epoch 29 got loss 0.92426 with train accuracy 0.97292, train top3 1.00000, train global 0.98104 and test accuracy 0.67500, test top3 0.86250, test global 0.73125
# On epoch 30 got loss 0.89280 with train accuracy 0.95833, train top3 0.99792, train global 0.97021 and test accuracy 0.72500, test top3 0.91250, test global 0.78125
# On epoch 31 got loss 0.81579 with train accuracy 0.97917, train top3 1.00000, train global 0.98542 and test accuracy 0.72500, test top3 0.87500, test global 0.77000
# On epoch 32 got loss 0.84686 with train accuracy 0.97292, train top3 1.00000, train global 0.98104 and test accuracy 0.67500, test top3 0.86250, test global 0.73125
# On epoch 33 got loss 0.78485 with train accuracy 0.98333, train top3 1.00000, train global 0.98833 and test accuracy 0.72500, test top3 0.91250, test global 0.78125
# On epoch 34 got loss 0.75501 with train accuracy 0.98750, train top3 1.00000, train global 0.99125 and test accuracy 0.73750, test top3 0.88750, test global 0.78250
# On epoch 35 got loss 0.72875 with train accuracy 0.98750, train top3 1.00000, train global 0.99125 and test accuracy 0.72500, test top3 0.87500, test global 0.77000
# On epoch 36 got loss 0.67346 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.70000, test top3 0.91250, test global 0.76375
# On epoch 37 got loss 0.67413 with train accuracy 0.99375, train top3 1.00000, train global 0.99562 and test accuracy 0.75000, test top3 0.90000, test global 0.79500
# On epoch 38 got loss 0.60977 with train accuracy 0.99792, train top3 1.00000, train global 0.99854 and test accuracy 0.77500, test top3 0.92500, test global 0.82000
# On epoch 39 got loss 0.61157 with train accuracy 0.99583, train top3 1.00000, train global 0.99708 and test accuracy 0.76250, test top3 0.92500, test global 0.81125
# On epoch 40 got loss 0.58462 with train accuracy 0.99792, train top3 1.00000, train global 0.99854 and test accuracy 0.71250, test top3 0.91250, test global 0.77250
# On epoch 41 got loss 0.59992 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.76250, test top3 0.91250, test global 0.80750
# On epoch 42 got loss 0.52947 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.78750, test top3 0.91250, test global 0.82500
# On epoch 43 got loss 0.50016 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.76250, test top3 0.93750, test global 0.81500
# On epoch 44 got loss 0.53447 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 45 got loss 0.49049 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.77500, test top3 0.92500, test global 0.82000
# On epoch 46 got loss 0.47174 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.78750, test top3 0.91250, test global 0.82500
# On epoch 47 got loss 0.41688 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.80000, test top3 0.93750, test global 0.84125
# On epoch 48 got loss 0.45102 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.87500, test top3 0.95000, test global 0.89750
# On epoch 49 got loss 0.40640 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.81250, test top3 0.93750, test global 0.85000
# On epoch 50 got loss 0.41044 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.83750, test top3 0.96250, test global 0.87500
# On epoch 51 got loss 0.41190 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.81250, test top3 0.93750, test global 0.85000
# On epoch 52 got loss 0.38424 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.83750, test top3 0.93750, test global 0.86750
# On epoch 53 got loss 0.38895 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.81250, test top3 0.93750, test global 0.85000
# On epoch 54 got loss 0.35748 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.96250, test global 0.89250
# On epoch 55 got loss 0.36953 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.83750, test top3 0.96250, test global 0.87500
# On epoch 56 got loss 0.34306 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.80000, test top3 0.92500, test global 0.83750
# On epoch 57 got loss 0.37927 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.83750, test top3 0.95000, test global 0.87125
# On epoch 58 got loss 0.29566 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.81250, test top3 0.95000, test global 0.85375
# On epoch 59 got loss 0.32576 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.87500, test top3 0.96250, test global 0.90125
# On epoch 60 got loss 0.30878 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.83750, test top3 0.95000, test global 0.87125
# On epoch 61 got loss 0.31600 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.93750, test global 0.88500
# On epoch 62 got loss 0.31273 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.95000, test global 0.88875
# On epoch 63 got loss 0.28219 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.97500, test global 0.88750
# On epoch 64 got loss 0.29035 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.83750, test top3 0.97500, test global 0.87875
# On epoch 65 got loss 0.26262 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.88750, test top3 0.93750, test global 0.90250
# On epoch 66 got loss 0.26624 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.81250, test top3 0.95000, test global 0.85375
# On epoch 67 got loss 0.26374 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.81250, test top3 0.92500, test global 0.84625
# On epoch 68 got loss 0.29244 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.93750, test global 0.88500
# On epoch 69 got loss 0.26536 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.82500, test top3 0.93750, test global 0.85875
# On epoch 70 got loss 0.23619 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.93750, test global 0.88500
# On epoch 71 got loss 0.25196 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.78750, test top3 0.95000, test global 0.83625
# On epoch 72 got loss 0.24175 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.83750, test top3 0.93750, test global 0.86750
# On epoch 73 got loss 0.24039 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.87500, test top3 0.93750, test global 0.89375
# On epoch 74 got loss 0.22056 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.93750, test global 0.88500
# On epoch 75 got loss 0.20771 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.81250, test top3 0.96250, test global 0.85750
# On epoch 76 got loss 0.20166 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.82500, test top3 0.95000, test global 0.86250
# On epoch 77 got loss 0.21081 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.87500, test top3 0.93750, test global 0.89375
# On epoch 78 got loss 0.18861 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.95000, test global 0.88875
# On epoch 79 got loss 0.21634 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.83750, test top3 0.96250, test global 0.87500
# On epoch 80 got loss 0.22279 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.83750, test top3 0.92500, test global 0.86375
# On epoch 81 got loss 0.18737 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.83750, test top3 0.95000, test global 0.87125
# On epoch 82 got loss 0.18589 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.83750, test top3 0.92500, test global 0.86375
# On epoch 83 got loss 0.16895 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.91250, test global 0.86875
# On epoch 84 got loss 0.17873 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.83750, test top3 0.92500, test global 0.86375
# On epoch 85 got loss 0.18459 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.93750, test global 0.88500
# On epoch 86 got loss 0.18909 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.90000, test global 0.87375
# On epoch 87 got loss 0.17184 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.87500, test top3 0.95000, test global 0.89750
# On epoch 88 got loss 0.16359 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.96250, test global 0.88375
# On epoch 89 got loss 0.17867 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.93750, test global 0.87625
# On epoch 90 got loss 0.16056 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.96250, test global 0.88375
# On epoch 91 got loss 0.15113 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.83750, test top3 0.97500, test global 0.87875
# On epoch 92 got loss 0.14469 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.87500, test top3 0.93750, test global 0.89375
# On epoch 93 got loss 0.18910 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 94 got loss 0.14260 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.95000, test global 0.88875
# On epoch 95 got loss 0.15947 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.83750, test top3 0.93750, test global 0.86750
# On epoch 96 got loss 0.12801 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.83750, test top3 0.93750, test global 0.86750
# On epoch 97 got loss 0.14436 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.83750, test top3 0.96250, test global 0.87500
# On epoch 98 got loss 0.17285 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 99 got loss 0.14766 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 100 got loss 0.15337 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.92500, test global 0.88125
# On epoch 101 got loss 0.15051 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.80000, test top3 0.96250, test global 0.84875
# On epoch 102 got loss 0.16407 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.83750, test top3 0.96250, test global 0.87500
# On epoch 103 got loss 0.14818 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.96250, test global 0.88375
# On epoch 104 got loss 0.14086 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.92500, test global 0.88125
# On epoch 105 got loss 0.13201 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.93750, test global 0.88500
# On epoch 106 got loss 0.11956 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.87500, test top3 0.96250, test global 0.90125
# On epoch 107 got loss 0.14618 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.88750, test top3 0.97500, test global 0.91375
# On epoch 108 got loss 0.11988 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.87500, test top3 0.97500, test global 0.90500
# On epoch 109 got loss 0.12025 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.97500, test global 0.88750
# On epoch 110 got loss 0.13622 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.83750, test top3 0.95000, test global 0.87125
# On epoch 111 got loss 0.12288 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.92500, test global 0.87250
# On epoch 112 got loss 0.12171 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.82500, test top3 0.95000, test global 0.86250
# On epoch 113 got loss 0.13008 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.83750, test top3 0.96250, test global 0.87500
# On epoch 114 got loss 0.11059 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.93750, test global 0.87625
# On epoch 115 got loss 0.12310 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 116 got loss 0.09566 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.83750, test top3 0.95000, test global 0.87125
# On epoch 117 got loss 0.10387 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.82500, test top3 0.92500, test global 0.85500
# On epoch 118 got loss 0.12727 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.83750, test top3 0.93750, test global 0.86750
# On epoch 119 got loss 0.12905 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.93750, test global 0.87625
# On epoch 120 got loss 0.11443 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.87500, test top3 0.96250, test global 0.90125
# On epoch 121 got loss 0.10499 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.93750, test global 0.87625
# On epoch 122 got loss 0.11654 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.93750, test global 0.87625
# On epoch 123 got loss 0.12014 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.80000, test top3 0.97500, test global 0.85250
# On epoch 124 got loss 0.12311 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.92500, test global 0.87250
# On epoch 125 got loss 0.09894 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.96250, test global 0.88375
# On epoch 126 got loss 0.10255 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.97500, test global 0.89625
# On epoch 127 got loss 0.09817 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.81250, test top3 0.95000, test global 0.85375
# On epoch 128 got loss 0.10660 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.95000, test global 0.88875
# On epoch 129 got loss 0.08834 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.88750, test top3 0.96250, test global 0.91000
# On epoch 130 got loss 0.09274 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.88750, test top3 0.95000, test global 0.90625
# On epoch 131 got loss 0.10162 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.87500, test top3 0.92500, test global 0.89000
# On epoch 132 got loss 0.09765 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.83750, test top3 0.95000, test global 0.87125
# On epoch 133 got loss 0.10649 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.83750, test top3 0.95000, test global 0.87125
# On epoch 134 got loss 0.09185 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.82500, test top3 0.97500, test global 0.87000
# On epoch 135 got loss 0.09113 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 136 got loss 0.08997 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.93750, test global 0.88500
# On epoch 137 got loss 0.09454 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.81250, test top3 0.92500, test global 0.84625
# On epoch 138 got loss 0.09564 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.82500, test top3 0.96250, test global 0.86625
# On epoch 139 got loss 0.09019 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.96250, test global 0.89250
# On epoch 140 got loss 0.09478 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.83750, test top3 0.91250, test global 0.86000
# On epoch 141 got loss 0.08728 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.95000, test global 0.88875
# On epoch 142 got loss 0.09046 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 143 got loss 0.09593 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.83750, test top3 0.93750, test global 0.86750
# On epoch 144 got loss 0.09343 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.82500, test top3 0.95000, test global 0.86250
# On epoch 145 got loss 0.08570 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.87500, test top3 0.93750, test global 0.89375
# On epoch 146 got loss 0.08658 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.92500, test global 0.87250
# On epoch 147 got loss 0.08925 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.92500, test global 0.87250
# On epoch 148 got loss 0.07916 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.92500, test global 0.88125
# On epoch 149 got loss 0.08976 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.95000, test global 0.88875
# On epoch 150 got loss 0.08657 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.96250, test global 0.89250
# On epoch 151 got loss 0.08283 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.88750, test top3 0.97500, test global 0.91375
# On epoch 152 got loss 0.07850 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.82500, test top3 0.92500, test global 0.85500
# On epoch 153 got loss 0.08532 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.93750, test global 0.87625
# On epoch 154 got loss 0.08853 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.82500, test top3 0.93750, test global 0.85875
# On epoch 155 got loss 0.08183 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.82500, test top3 0.95000, test global 0.86250
# On epoch 156 got loss 0.07143 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.92500, test global 0.87250
# On epoch 157 got loss 0.07597 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.93750, test global 0.87625
# On epoch 158 got loss 0.07618 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.83750, test top3 0.93750, test global 0.86750
# On epoch 159 got loss 0.09255 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.82500, test top3 0.93750, test global 0.85875
# On epoch 160 got loss 0.07602 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.92500, test global 0.87250
# On epoch 161 got loss 0.07431 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.83750, test top3 0.92500, test global 0.86375
# On epoch 162 got loss 0.08124 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.93750, test global 0.87625
# On epoch 163 got loss 0.08206 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.83750, test top3 0.92500, test global 0.86375
# On epoch 164 got loss 0.06817 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.93750, test global 0.88500
# On epoch 165 got loss 0.07431 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.83750, test top3 0.93750, test global 0.86750
# On epoch 166 got loss 0.08032 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.93750, test global 0.88500
# On epoch 167 got loss 0.08054 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.92500, test global 0.87250
# On epoch 168 got loss 0.07956 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.83750, test top3 0.97500, test global 0.87875
# On epoch 169 got loss 0.07322 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.96250, test global 0.89250
# On epoch 170 got loss 0.07019 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.97500, test global 0.88750
# On epoch 171 got loss 0.07229 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 172 got loss 0.07423 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.83750, test top3 0.97500, test global 0.87875
# On epoch 173 got loss 0.05893 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.97500, test global 0.88750
# On epoch 174 got loss 0.06485 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.92500, test global 0.87250
# On epoch 175 got loss 0.06445 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.92500, test global 0.87250
# On epoch 176 got loss 0.07690 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.92500, test global 0.87250
# On epoch 177 got loss 0.06418 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.93750, test global 0.87625
# On epoch 178 got loss 0.06362 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.87500, test top3 0.96250, test global 0.90125
# On epoch 179 got loss 0.06441 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 180 got loss 0.06069 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.97500, test global 0.88750
# On epoch 181 got loss 0.05898 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 182 got loss 0.05474 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.93750, test global 0.87625
# On epoch 183 got loss 0.06984 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.92500, test global 0.87250
# On epoch 184 got loss 0.07304 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 185 got loss 0.07997 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.83750, test top3 0.96250, test global 0.87500
# On epoch 186 got loss 0.06784 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.83750, test top3 0.96250, test global 0.87500
# On epoch 187 got loss 0.04711 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.97500, test global 0.88750
# On epoch 188 got loss 0.05969 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.83750, test top3 0.95000, test global 0.87125
# On epoch 189 got loss 0.06340 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.96250, test global 0.89250
# On epoch 190 got loss 0.04907 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.93750, test global 0.88500
# On epoch 191 got loss 0.05731 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.87500, test top3 0.95000, test global 0.89750
# On epoch 192 got loss 0.07174 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.83750, test top3 0.97500, test global 0.87875
# On epoch 193 got loss 0.05880 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 194 got loss 0.05452 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 195 got loss 0.05364 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.96250, test global 0.88375
# On epoch 196 got loss 0.06609 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.88750, test top3 0.96250, test global 0.91000
# On epoch 197 got loss 0.05643 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.83750, test top3 0.96250, test global 0.87500
# On epoch 198 got loss 0.05729 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.83750, test top3 0.92500, test global 0.86375
# On epoch 199 got loss 0.05045 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 200 got loss 0.06326 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.81250, test top3 0.97500, test global 0.86125
# On epoch 201 got loss 0.05034 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.82500, test top3 0.96250, test global 0.86625
# On epoch 202 got loss 0.06435 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 203 got loss 0.05656 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 204 got loss 0.04889 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.82500, test top3 0.96250, test global 0.86625
# On epoch 205 got loss 0.05454 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 206 got loss 0.05135 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 207 got loss 0.07204 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.93750, test global 0.87625
# On epoch 208 got loss 0.05460 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.96250, test global 0.88375
# On epoch 209 got loss 0.04877 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.92500, test global 0.87250
# On epoch 210 got loss 0.04971 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.93750, test global 0.87625
# On epoch 211 got loss 0.04997 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.83750, test top3 0.92500, test global 0.86375
# On epoch 212 got loss 0.06053 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.83750, test top3 0.93750, test global 0.86750
# On epoch 213 got loss 0.04507 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.93750, test global 0.87625
# On epoch 214 got loss 0.06800 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 215 got loss 0.05964 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 216 got loss 0.05607 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.93750, test global 0.87625
# On epoch 217 got loss 0.05343 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 218 got loss 0.05196 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.83750, test top3 0.93750, test global 0.86750
# On epoch 219 got loss 0.06326 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.92500, test global 0.88125
# On epoch 220 got loss 0.05567 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.93750, test global 0.88500
# On epoch 221 got loss 0.06138 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.92500, test global 0.88125
# On epoch 222 got loss 0.04875 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.92500, test global 0.87250
# On epoch 223 got loss 0.04502 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.93750, test global 0.87625
# On epoch 224 got loss 0.05205 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.95000, test global 0.88875
# On epoch 225 got loss 0.07277 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 226 got loss 0.04603 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.93750, test global 0.87625
# On epoch 227 got loss 0.05029 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.96250, test global 0.88375
# On epoch 228 got loss 0.04676 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 229 got loss 0.04801 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 230 got loss 0.05079 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.95000, test global 0.88875
# On epoch 231 got loss 0.04367 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.96250, test global 0.89250
# On epoch 232 got loss 0.06549 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.95000, test global 0.88875
# On epoch 233 got loss 0.04392 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.93750, test global 0.88500
# On epoch 234 got loss 0.05497 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.95000, test global 0.88875
# On epoch 235 got loss 0.04787 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 236 got loss 0.05776 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.93750, test global 0.87625
# On epoch 237 got loss 0.05344 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 238 got loss 0.05552 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.87500, test top3 0.96250, test global 0.90125
# ...
# On epoch 1122 got loss 0.03967 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 1123 got loss 0.04335 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.96250, test global 0.89250
# On epoch 1124 got loss 0.03661 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.96250, test global 0.88375
# On epoch 1125 got loss 0.03839 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.96250, test global 0.88375
# On epoch 1126 got loss 0.04481 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.95000, test global 0.88875
# On epoch 1127 got loss 0.03580 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.95000, test global 0.88875
# On epoch 1128 got loss 0.04476 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.96250, test global 0.88375
# On epoch 1129 got loss 0.03192 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.96250, test global 0.89250
# On epoch 1130 got loss 0.04698 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.96250, test global 0.89250
# On epoch 1131 got loss 0.05052 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.95000, test global 0.88875
# On epoch 1132 got loss 0.04480 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.95000, test global 0.88875
# On epoch 1133 got loss 0.05214 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.96250, test global 0.89250
# On epoch 1134 got loss 0.03781 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.96250, test global 0.88375
# On epoch 1135 got loss 0.04028 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 1136 got loss 0.04253 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.96250, test global 0.88375
# On epoch 1137 got loss 0.04165 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.96250, test global 0.89250
# On epoch 1138 got loss 0.04069 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.96250, test global 0.89250
# On epoch 1139 got loss 0.04626 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.87500, test top3 0.96250, test global 0.90125
# On epoch 1140 got loss 0.03652 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 1141 got loss 0.03526 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.96250, test global 0.88375
# On epoch 1142 got loss 0.05061 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 1143 got loss 0.03789 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 1144 got loss 0.03842 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.95000, test global 0.88875
# On epoch 1145 got loss 0.03690 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 1146 got loss 0.03925 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 1147 got loss 0.04245 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.95000, test global 0.88875
# On epoch 1148 got loss 0.04012 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.96250, test global 0.89250
# On epoch 1149 got loss 0.04243 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.96250, test global 0.88375
# On epoch 1150 got loss 0.04619 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.96250, test global 0.88375
# On epoch 1151 got loss 0.03519 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.96250, test global 0.89250
# On epoch 1152 got loss 0.04560 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.96250, test global 0.89250
# On epoch 1153 got loss 0.03870 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.96250, test global 0.89250
# On epoch 1154 got loss 0.04360 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.96250, test global 0.88375
# On epoch 1155 got loss 0.04299 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.95000, test global 0.88875
# On epoch 1156 got loss 0.04697 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.93750, test global 0.88500
# On epoch 1157 got loss 0.03671 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.96250, test global 0.88375
# On epoch 1158 got loss 0.04981 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 1159 got loss 0.05487 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.96250, test global 0.88375
# On epoch 1160 got loss 0.03974 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.96250, test global 0.88375
# On epoch 1161 got loss 0.04790 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.96250, test global 0.88375
# On epoch 1162 got loss 0.03602 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.96250, test global 0.88375
# On epoch 1163 got loss 0.03884 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.96250, test global 0.88375
# On epoch 1164 got loss 0.05475 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 1165 got loss 0.03342 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.95000, test global 0.88875
# On epoch 1166 got loss 0.03575 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.96250, test global 0.89250
# On epoch 1167 got loss 0.03344 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 1168 got loss 0.04774 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.96250, test global 0.88375
# On epoch 1169 got loss 0.03256 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 1170 got loss 0.03851 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.96250, test global 0.89250
# On epoch 1171 got loss 0.03476 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 1172 got loss 0.04037 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 1173 got loss 0.04468 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.95000, test global 0.88875
# On epoch 1174 got loss 0.04306 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.95000, test global 0.88875
# On epoch 1175 got loss 0.04230 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.96250, test global 0.89250
# On epoch 1176 got loss 0.03870 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.93750, test global 0.87625
# On epoch 1177 got loss 0.03132 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 1178 got loss 0.04292 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 1179 got loss 0.04528 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 1180 got loss 0.03527 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 1181 got loss 0.05294 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.95000, test global 0.88875
# On epoch 1182 got loss 0.03440 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 1183 got loss 0.03950 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.96250, test global 0.88375
# On epoch 1184 got loss 0.03324 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.96250, test global 0.88375
# On epoch 1185 got loss 0.03325 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.96250, test global 0.89250
# On epoch 1186 got loss 0.05090 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.96250, test global 0.89250
# On epoch 1187 got loss 0.04545 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.96250, test global 0.88375
# On epoch 1188 got loss 0.03967 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.95000, test global 0.88875
# On epoch 1189 got loss 0.03297 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.96250, test global 0.88375
# On epoch 1190 got loss 0.05330 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.96250, test global 0.88375
# On epoch 1191 got loss 0.04232 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.96250, test global 0.88375
# On epoch 1192 got loss 0.04067 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.95000, test global 0.88000
# On epoch 1193 got loss 0.04568 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.96250, test global 0.89250
# On epoch 1194 got loss 0.04919 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.96250, test global 0.89250
# On epoch 1195 got loss 0.03718 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.96250, test global 0.88375
# On epoch 1196 got loss 0.03541 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.96250, test global 0.88375
# On epoch 1197 got loss 0.04239 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.96250, test global 0.89250
# On epoch 1198 got loss 0.04198 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.96250, test global 0.89250
# On epoch 1199 got loss 0.03798 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.86250, test top3 0.96250, test global 0.89250
# On epoch 1200 got loss 0.03498 with train accuracy 1.00000, train top3 1.00000, train global 1.00000 and test accuracy 0.85000, test top3 0.96250, test global 0.88375

# %%
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

n_test = len(test_dataset)
n_clases = 40

matriz_probs = torch.zeros((n_test, n_clases))
#matriz_probs_np = matriz_probs.numpy()   VERSION DE NUMPY, SI SE QUIERE USAR EN LUGAR DE TENSOR
#np.save("matriz_probs_test.npy", matriz_probs_np)   SIRVE PARA GUARDAR LA MATRIZ EN UN ARCHIVO .npy SI SE QUIERE USAR NUMPY EN LUGAR DE TENSOR

model.eval()

indice = 0
with torch.no_grad():
    for x, _ in test_loader:
        x = x.to(device)

        logits = model.forward_eval(x, apply_link=False)

        probs = torch.softmax(logits, dim=1).cpu()

        batch_size = probs.shape[0]
        matriz_probs[indice:indice + batch_size, :] = probs
        indice += batch_size

print(matriz_probs.shape)
print(matriz_probs)
# Out:
# torch.Size([80, 40])
# tensor([[9.9151e-05, 4.0771e-05, 1.6778e-03,  ..., 9.7678e-01, 2.6464e-05,
#          1.1348e-04],
#         [8.1327e-04, 2.4915e-04, 9.0260e-03,  ..., 4.6572e-04, 1.0655e-04,
#          1.7236e-03],
#         [4.2206e-05, 2.0677e-04, 3.5220e-04,  ..., 4.4210e-06, 1.6485e-05,
#          3.0432e-03],
#         ...,
#         [4.4384e-04, 5.5261e-05, 1.8246e-05,  ..., 1.4567e-04, 4.7950e-05,
#          5.5140e-04],
#         [6.0986e-05, 3.1244e-05, 8.5120e-06,  ..., 1.5297e-05, 7.2617e-06,
#          6.5516e-05],
#         [1.5450e-02, 6.4566e-03, 2.6644e-04,  ..., 9.3105e-04, 9.3469e-04,
#          6.3223e-04]])

# %%
best_epoch = np.argmax(three_drop05_test_acc)
best_test_acc = three_drop05_test_acc[best_epoch]
best_train_acc = three_drop05_train_acc[best_epoch]
best_loss = three_drop05_loss[best_epoch]


print(f"Mejor época: {best_epoch}")
print(f"Mejor test accuracy: {best_test_acc:.4f}")
print(f"Mejor test top3: {three_drop05_test_top3[best_epoch]:.4f}")
print(f"Mejor test global: {three_drop05_test_global[best_epoch]:.4f}")
print(f"Train accuracy en esa época: {best_train_acc:.4f}")
print(f"Train top3 en esa época: {three_drop05_train_top3[best_epoch]:.4f}")
print(f"Train global en esa época: {three_drop05_train_global[best_epoch]:.4f}")
print(f"Loss en esa época: {best_loss:.4f}")
# Out:
# Mejor época: 65
# Mejor test accuracy: 0.8875
# Mejor test top3: 0.9375
# Mejor test global: 0.9025
# Train accuracy en esa época: 1.0000
# Train top3 en esa época: 1.0000
# Train global en esa época: 1.0000
# Loss en esa época: 0.2626

# %%
fig, (ax11, ax21, ax31, ax41) = plt.subplots(4, 1, figsize=(8, 16))

## Plot cross entropy loss
ax11.plot(range(len(three_drop05_loss)), three_drop05_loss,
          label='3 hidden layer YES dropout', color='C1', linestyle='--')
ax11.set_ylim([0.0, 1.5])
ax11.set_ylabel('Cross entropy loss')
ax11.set_xlabel('epochs')
ax11.legend()

## Plot accuracy (train y test)
ax21.plot(range(len(three_drop05_train_acc)), three_drop05_train_acc,
          label='train accuracy', color='C1', linestyle='--')
ax21.plot(range(len(three_drop05_test_acc)), three_drop05_test_acc,
          label='test accuracy', color='C0', linestyle='--')
ax21.set_ylim([0.0, 1.0])
ax21.set_ylabel('Accuracy')
ax21.set_xlabel('epochs')
ax21.legend()

## Plot top-3 (train y test)
ax31.plot(range(len(three_drop05_train_top3)), three_drop05_train_top3,
          label='train top-3', color='C2', linestyle='--')
ax31.plot(range(len(three_drop05_test_top3)), three_drop05_test_top3,
          label='test top-3', color='C3', linestyle='--')
ax31.set_ylim([0.0, 1.0])
ax31.set_ylabel('Top-3')
ax31.set_xlabel('epochs')
ax31.legend()

## Plot global metric (train y test)
ax41.plot(range(len(three_drop05_train_global)), three_drop05_train_global,
          label='train global', color='C4', linestyle='--')
ax41.plot(range(len(three_drop05_test_global)), three_drop05_test_global,
          label='test global', color='C5', linestyle='--')
ax41.set_ylim([0.0, 1.0])
ax41.set_ylabel('0.7*acc + 0.3*top3')
ax41.set_xlabel('epochs')
ax41.legend()

plt.tight_layout()
plt.show()
